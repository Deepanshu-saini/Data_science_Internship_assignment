# %%
import pandas as pd
rf= pd.read_csv(r"/content/SampleQuestionFile_q.txt",delimiter="###0",header=None,on_bad_lines="skip")
rf.to_csv(r"/content/csvfile.csv")
col=["sno","question No."]
df=pd.read_csv(r"/content/csvfile.csv",names=col,skiprows=1)
df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#      sno                                       question No.
# 0      0  1. $\text { I : }(p \Rightarrow q) \vee(q \Rig...
# 1      1                                                @@@
# 2      2  (a) $\mathrm{I}$  is tautology and $\mathrm{II...
# 3      3  (b) $\mathrm{I}$  is fallacy and $\mathrm{II}$...
# 4      4  (c) $\mathrm{I}$  and $\mathrm{II}$  both are ...
# ..   ...                                                ...
# 139  139                                                @@@
# 140  140  29. Let $T$ and $D$ be number of triangles and...
# 141  141                                                @@@
# ...

# %%
data=df['question No.']
quesno=[]
ques=[]
option1=[]
option2=[]
option3=[]
option4=[]
for x in range(len(df)):
  if(data[x][0].isdigit()):
    if(data[x][1].isdigit()):
      quesno.append(data[x][0:2])
    else:
      quesno.append(data[x][0:1])
    ques.append(data[x][3:])
  if(data[x]=="@@@"):
    continue
  if(data[x][0:3]=="(a)"):
    option1.append(data[x][3:])
  if(data[x][0:3]=="(b)"):
    option2.append(data[x][3:])
  if(data[x][0:3]=="(c)"):
    option3.append(data[x][3:])
  if(data[x][0:3]=="(d)"):
    option4.append(data[x][3:])
df.drop(["sno"],axis=1,inplace=True)
df.drop(["question No."],axis=1,inplace=True)
for x in range(30):
  option1.append(None)
  option2.append(None)
  option3.append(None)
  option4.append(None)
dn=df.head(30)
dn.to_csv(r"/content/newfile.csv")
dn["quesno"]=quesno
dn["ques"]=ques
dn["option1"]=option1
dn["option2"]=option2
dn["option3"]=option3
dn["option4"]=option4
dn
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
rfs= pd.read_csv(r"/content/SampleSolutionFile_s.txt",delimiter="###0",header=None,on_bad_lines="skip")
rfs.to_csv(r"/content/solcsvfile.csv")
col1=["sno","sol."]
ds=pd.read_csv(r"/content/solcsvfile.csv",names=col1,skiprows=1)
ds
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#      sno                                               sol.
# 0      0                                             1. (c)
# 1      1                     \begin{tabular}{c|c|c|c|c|c|c}
# 2      2  \hline$p$ & $\sim p$ & $q$ & $p \Rightarrow q$...
# 3      3  \hline $\mathrm{T}$ & $\mathrm{F}$ & $\mathrm{...
# 4      4  $\mathrm{T}$ & $\mathrm{F}$ & $\mathrm{F}$ & $...
# ..   ...                                                ...
# 203  203                                            30. (1)
# 204  204  For $\left(x^{2}+\frac{1}{\sqrt{x}}\right)^{10...
# 205  205  For $\left(\sqrt{x}+\frac{1}{x^{2}}\right)^{10...
# ...

# %%
ans=ds["sol."]
ans_key={}
ans_sol={}
i=0
s=[]
for y in range(len(ans)):
  if(ans[y][0].isdigit()):
    s=[]
    if(ans[y][1].isdigit()):
      ans_key[ans[y][0:2]]=ans[y][4:]
    else:
      ans_key[ans[y][0]]=ans[y][3:]
    i+=1
  else:
    s.append(ans[y])
    ans_sol[str(i)]=s
dn["key"]=dn["quesno"].map(ans_key)
dn["solution"]=dn["quesno"].map(ans_sol)
dn
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    quesno                                               ques  \
# 0       1  $\text { I : }(p \Rightarrow q) \vee(q \Righta...
# 1       2  Statement $\mathrm{I}$: $x^{2}+y^{2}=12$ and $...
# 2       3  Two fixed points are $A(a, 0)$ and $B(-a, 0)$....
# ...

# %%
s1=dn["solution"]
for x in range(len(s1)):
  s1[x]="".join(s1[x])
dn
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#    quesno                                               ques  \
# 0       1  $\text { I : }(p \Rightarrow q) \vee(q \Righta...
# 1       2  Statement $\mathrm{I}$: $x^{2}+y^{2}=12$ and $...
# 2       3  Two fixed points are $A(a, 0)$ and $B(-a, 0)$....
# 3       4  The sum of $80$ terms of the series $11,102,10...
# 4       5  The area above the $x$-axis enclosed by the cu...
# 5       6  If a circles $x^{2}+y^{2}=a^{2}$ and the recta...
# 6       7  The value of $a$ in order that $f(x)=\sin x-\c...
# 7       8  The centre of circle touching $Y$-axis at $(0,...
# ...
